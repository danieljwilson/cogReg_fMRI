# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
# Import Libraries
library(tidyverse)
library(data.table)

## set universal plot size:
options(repr.plot.width=7, repr.plot.height=3.5)

# avoids scientific notation
options(scipen=999)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %% [markdown]
# ## Load and manipulate data

# %%
# Read in data
df = as_tibble(read_csv("data/questionnaires.csv"), stringsAsFactors = FALSE)
# Select fMRI study subjects
fmri_sub <- grepl("FRMRI*", df[, 2][[1]])
df = df[fmri_sub, ]

# Rename Columns
names(df)[1:13] = c("demo_time",
                    "subject",
                    "demo_gender",
                    "demo_race",
                    "demo_age",
                    "demo_weight",
                    "demo_height",
                    "demo_yrs_canada",
                    "demo_diet",
                    "demo_diet_detail",
                    "demo_familiar",
                    "demo_previous_food",
                    "demo_previous_food_time")

# Just want id number
df <- df %>%
  mutate(
    subject = readr::parse_number(subject)
  )
  
# rename condition effects
cols = c(14,16,17,15,18,19,20,114,115,116,117)
colnames(df)[cols] <- c(paste0("ce_", 1:11))

# rename strategy questions
cols = c(21:28, 118:125)
colnames(df)[cols] <- c(paste0("s_", 1:16))

# rename Three Factor Eating Questionnaire
cols = c(29:46)
colnames(df)[cols] <- c(paste0("tfeq_", 1:18))

# rename rapid food screener
    # fruits and veg
cols = c(47:56)
colnames(df)[cols] <- c(paste0("rfs_fv_", 1:10))

    # fat
cols = c(57:73)
colnames(df)[cols] <- c(paste0("rfs_f_", 1:17))

# BIS 11
cols = c(74:103)
colnames(df)[cols] <- c(paste0("bis_", 1:30))

# Perceived Stress Scale
cols = c(104:113)
colnames(df)[cols] <- c(paste0("pss_", 1:10))

# reorder
df =df[,order(colnames(df))]
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   `What time did you eat the food you indicated in the last question?` = col_time(format = ""),
#   `How difficult was it to make choices during trials when you were asked to RESPOND NATURALLY?` = col_double(),
#   `How difficult was it to make choices during trials when you were asked to DECREASE YOUR DESIRE?` = col_double(),
#   `How much did you think about the health of the foods when choosing NATURALLY?` = col_double(),
#   `How much did you try to decrease your desire for the foods when choosing NATURALLY?` = col_double(),
#   `How much did you think about the health of the foods when trying to DECREASE DESIRE?` = col_double(),
#   `How much did you try to reduce your craving for the foods when trying to DECREASE DESIRE?` = col_double(),
#   `How successful do you think you were in controlling your responses to the food when you were asked to DECREASE DESIRE?` = col_double(),
#   `1. I tried to think about how UNHEALTHY the foods were.` = col_double(),
#   `2. I tried to avoid thinking about how hungry I was.` = col_double(),
#   `3. I tried to change the way I thought about the food.` = col_double(),
#   `4. I tried not to look at the pictures of the food.` = col_double(),
#   `5. I tried to think about how HEALTHY the foods were.` = col_double(),
#   `6. I didn't change how much I wanted the food, but I changed which foods I chose anyway.` = col_double(),
#   `7. I tried to decrease my desire for the foods.` = col_double(),
#   `8. I tried to avoid thinking about how tasty the foods were.` = col_double(),
#   `On a scale of 1 to 8, where 1 means no restraint in eating (eating whatever you want, whenever you want it) and 8 means total restraint (constantly limiting food intake and never “giving in”), what number would you give yourself?` = col_double(),
#   `How difficult was it to make choices during trials when you were asked to FOCUS ON HEALTH?` = col_double(),
#   `How much did you think about the health of the foods when trying to FOCUS ON HEALTH?` = col_double(),
#   `How much did you try to reduce your craving for the foods when trying to FOCUS ON HEALTH?` = col_double()
#   # ... with 9 more columns
# )
# See spec(...) for full column specifications.

# %%
# want to look only at the subjects that were kept
good_subjects = c(101:104, 106:112, 114, 116, 118:121, 123:126, 129:137, 139:140, 142:148, 150, 152:158, 162:164)
# remove "bad" subjects
df_good = df %>%
    filter(subject %in% good_subjects)

# %%
names(df_good)
# Out:
#   [1] "bis_1"                   "bis_10"
#   [3] "bis_11"                  "bis_12"
#   [5] "bis_13"                  "bis_14"
#   [7] "bis_15"                  "bis_16"
#   [9] "bis_17"                  "bis_18"
#  [11] "bis_19"                  "bis_2"
#  [13] "bis_20"                  "bis_21"
#  [15] "bis_22"                  "bis_23"
#  [17] "bis_24"                  "bis_25"
#  [19] "bis_26"                  "bis_27"
#  [21] "bis_28"                  "bis_29"
#  [23] "bis_3"                   "bis_30"
#  [25] "bis_4"                   "bis_5"
#  [27] "bis_6"                   "bis_7"
#  [29] "bis_8"                   "bis_9"
#  [31] "ce_1"                    "ce_10"
#  [33] "ce_11"                   "ce_2"
#  [35] "ce_3"                    "ce_4"
#  [37] "ce_5"                    "ce_6"
#  [39] "ce_7"                    "ce_8"
#  [41] "ce_9"                    "demo_age"
#  [43] "demo_diet"               "demo_diet_detail"
#  [45] "demo_familiar"           "demo_gender"
#  [47] "demo_height"             "demo_previous_food"
#  [49] "demo_previous_food_time" "demo_race"
#  [51] "demo_time"               "demo_weight"
#  [53] "demo_yrs_canada"         "pss_1"
#  [55] "pss_10"                  "pss_2"
#  [57] "pss_3"                   "pss_4"
#  [59] "pss_5"                   "pss_6"
#  [61] "pss_7"                   "pss_8"
#  [63] "pss_9"                   "rfs_f_1"
#  [65] "rfs_f_10"                "rfs_f_11"
#  [67] "rfs_f_12"                "rfs_f_13"
#  [69] "rfs_f_14"                "rfs_f_15"
#  [71] "rfs_f_16"                "rfs_f_17"
#  [73] "rfs_f_2"                 "rfs_f_3"
#  [75] "rfs_f_4"                 "rfs_f_5"
#  [77] "rfs_f_6"                 "rfs_f_7"
#  [79] "rfs_f_8"                 "rfs_f_9"
#  [81] "rfs_fv_1"                "rfs_fv_10"
#  [83] "rfs_fv_2"                "rfs_fv_3"
#  [85] "rfs_fv_4"                "rfs_fv_5"
#  [87] "rfs_fv_6"                "rfs_fv_7"
#  [89] "rfs_fv_8"                "rfs_fv_9"
#  [91] "s_1"                     "s_10"
#  [93] "s_11"                    "s_12"
#  [95] "s_13"                    "s_14"
#  [97] "s_15"                    "s_16"
#  [99] "s_2"                     "s_3"
# [101] "s_4"                     "s_5"
# [103] "s_6"                     "s_7"
# [105] "s_8"                     "s_9"
# [107] "subject"                 "tfeq_1"
# [109] "tfeq_10"                 "tfeq_11"
# [111] "tfeq_12"                 "tfeq_13"
# [113] "tfeq_14"                 "tfeq_15"
# [115] "tfeq_16"                 "tfeq_17"
# [117] "tfeq_18"                 "tfeq_2"
# [119] "tfeq_3"                  "tfeq_4"
# [121] "tfeq_5"                  "tfeq_6"
# [123] "tfeq_7"                  "tfeq_8"
# [125] "tfeq_9"

# %%
head(df_good)
# Out:
#   bis_1        bis_10               bis_11       bis_12
# 1 Occasionally Rarely               Occasionally Occasionally
# 2 Often        Almost always/Always Often        Often
# 3 Often        Occasionally         Rarely       Almost always/Always
# 4 Often        Rarely               Occasionally Occasionally
# 5 Often        Occasionally         Rarely       Almost always/Always
# 6 Occasionally Almost always/Always Occasionally Occasionally
#   bis_13               bis_14       bis_15               bis_16
# 1 Occasionally         Occasionally Often                Occasionally
# 2 Almost always/Always Rarely       Almost always/Always Occasionally
# 3 Almost always/Always Rarely       Almost always/Always Rarely
# 4 Rarely               Rarely       Occasionally         Often
# 5 Often                Rarely       Occasionally         Occasionally
# 6 Rarely               Occasionally Often                Occasionally
#   bis_17       bis_18               ⋯ tfeq_17   tfeq_18 tfeq_2
# 1 Occasionally Occasionally         ⋯ Never     5       Definitely false
# 2 Occasionally Rarely               ⋯ Sometimes 2       Definitely false
# 3 Rarely       Almost always/Always ⋯ Rarely    6       Mostly false
# 4 Often        Often                ⋯ Never     2       Mostly false
# 5 Rarely       Occasionally         ⋯ Sometimes 6       Mostly false
# 6 Often        Occasionally         ⋯ Rarely    5       Definitely false
#   tfeq_3           tfeq_4           tfeq_5           tfeq_6
# 1 Mostly true      Mostly false     Mostly true      Mostly false
# 2 Definitely true  Definitely false Definitely false Mostly false
# 3 Mostly false     Mostly true      Mostly false     Mostly false
# 4 Definitely false Definitely false Mostly true      Mostly true
# 5 Mostly true      Mostly true      Mostly true      Mostly true
# 6 Mostly true      Mostly true      Mostly true      Mostly false
#   tfeq_7           tfeq_8           tfeq_9
# 1 Mostly false     Mostly false     Mostly true
# 2 Mostly true      Definitely false Definitely false
# 3 Mostly false     Mostly false     Mostly false
# 4 Definitely false Definitely false Mostly false
# 5 Mostly true      Mostly false     Mostly true
# 6 Mostly true      Mostly true      Mostly false

# %% [markdown]
# ## Recode Questions

# %% [markdown]
# ## Questionnaire Key

# %% [markdown]
# ---
# [Coding Google Sheet](https://docs.google.com/spreadsheets/d/1M_YAg-ALHN3SOx1DGVZ9EWd8rX8-QJuatQehSt9CCms/edit?usp=sharing)
#
# ---

# %% [markdown]
# # Demographics

# %%
table(df_good$demo_gender)
# Out:
# Female   Male
#     34     16
#   age  ageSD    ageMin ageMax
# 1 23.1 4.258245 18     38

# %%
tibble(age = mean(as.numeric(df_good$demo_age), na.rm = T), 
       ageSD = sd(as.numeric(df_good$demo_age), na.rm = T),
       ageMin = min(as.numeric(df_good$demo_age), na.rm = T),
       ageMax = max(as.numeric(df_good$demo_age), na.rm = T))

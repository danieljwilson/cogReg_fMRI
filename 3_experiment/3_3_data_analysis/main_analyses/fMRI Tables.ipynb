# %%
import numpy as np
import pandas as pd

from scipy.io import loadmat

# %%
mat = loadmat('matlab_files/TasteHealth_all_preference.mat')

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'TasteHealth_all_preference'])

# %%
mat['TasteHealth_all_preference']
# Out:
# array([[(array(['p-values adjusted for search volume'], dtype='<U35'), array([[array(['set'], dtype='<U3'), array(['set'], dtype='<U3'),
#         array(['cluster'], dtype='<U7'), array(['cluster'], dtype='<U7'),
#         array(['cluster'], dtype='<U7'), array(['cluster'], dtype='<U7'),
#         array(['peak'], dtype='<U4'), array(['peak'], dtype='<U4'),
#         array(['peak'], dtype='<U4'), array(['peak'], dtype='<U4'),
#         array(['peak'], dtype='<U4'), array([], dtype='<U1')],
#        [array(['p'], dtype='<U1'), array(['c'], dtype='<U1'),
#         array(['p(FWE-corr)'], dtype='<U11'),
#         array(['p(FDR-corr)'], dtype='<U11'),
#         array(['equivk'], dtype='<U6'), array(['p(unc)'], dtype='<U6'),
#         array(['p(FWE-corr)'], dtype='<U11'),
#         array(['p(FDR-corr)'], dtype='<U11'), array(['T'], dtype='<U1'),
#         array(['equivZ'], dtype='<U6'), array(['p(unc)'], dtype='<U6'),
#         array(['x,y,z {mm}'], dtype='<U10')],
# ...
